# %% [markdown]
# # Introduction to data visualization using MatplotLib

# %% [markdown]
# ## Data is only as good as it’s presented.
# ### Why are visualizations important?
# * Visualizations are the easiest way to analyze and absorb information.
# * Visuals help to easily understand the complex problem.
# * They help in identifying patterns, relationships, and outliers in data.
# * It helps in understanding business problems better and quickly.
# * It helps to build a compelling story based on visuals.
# * Insights gathered from the visuals help in building strategies for businesses.
# * It is also a precursor to many high-level data analysis for Exploratory Data Analysis(EDA) and Machine Learning(ML).

# %% [markdown]
# ## Matplotlib
# * Matplotlib is a 2-D plotting library that helps in visualizing figures.
# * Matplotlib emulates Matlab like graphs and visualizations.
# * Matlab is not free, is difficult to scale and as a programming language is tedious.
# * So, matplotlib in Python is used as it is a robust, free and easy library for data visualization.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Installing Matplotlib
# * `!pip install matplotlib` in the Jupyter Notebook or
# * cmd type conda install `-c conda-forge matplotlib`
# * `import matplotlib.pyplot as plt` for making it call the package module

# %% [markdown]
# ## Pandas Recall and Matplotlib basics
# * Importing required libraries using Pandas `pd.read_csv()`
# * Extracting important parts for plots using conditions on Pandas Dataframes.
# * `plt.plot()`for plotting line chart similarly in place of plot other functions are used for plotting.
# * `plot.xlabel` , `plt.ylabel` for labeling x and y-axis respectively.
# * `plt.xticks` , `plt.yticks` for labeling x and y-axis observation tick points respectively.
# * `plt.legend()` for signifying the observation variables.
# * `plt.title()` for setting the title of the plot.
# * `plot.show()` for displaying the plot.

# %% [markdown]
# ### Here you will learn:
# * 1.Histogram
# * 2.Piechart
# * 3.Line Chart
# * 4.Box plot
# * 5.Twin axis
# * 6.Stack plot
# * 7.Bar plot
# * 8.Scatter plot

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\gavin\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gavin\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\gavin\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gavin\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gavin\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\gavin\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\gavin\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gavin\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\gavin\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gavin\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gavin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## 1 Histogram : We should use histogram when we need the count of the variable in a plot.

# %%
#national park dataset
import pandas as pd
import matplotlib.pyplot as plt
np_data=pd.read_csv("national_parks.csv")

# %%
np_data.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
np_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         57 non-null     int64
#  1   Badlands     57 non-null     int64
#  2   GrandCanyon  57 non-null     int64
#  3   BryceCanyon  57 non-null     int64
# dtypes: int64(4)
# memory usage: 1.9 KB

# %%
plt.hist(np_data['GrandCanyon'],
        facecolor="lightgreen",
        edgecolor="blue",
        bins=10)
plt.xlabel("Count")
plt.ylabel("Frequency")
plt.title("Histogram plot of the Grand Canyon")
plt.show()

# %% [markdown]
# #### The cumulative property
# If True, then a histogram is computed where each bin gives the counts in that bin plus all bins for smaller values. The last bin gives the total number of datapoints.

# %%
plt.hist(np_data['GrandCanyon'],
        facecolor="lightgreen",
        edgecolor="blue",
        bins=10,
        cumulative=True)
plt.xlabel("bins")
plt.ylabel("Frequency")
plt.title("Histogram plot of the Grand Canyon")
plt.show()

# %% [markdown]
# #### Check the histogram to a range of values
# We only look at the data points within the range 2M-5M. This realigns the bins in the histogram

# %%
plt.hist(np_data['GrandCanyon'],
        facecolor="lightgreen",
        edgecolor="blue",
        bins=10,
        range=(2000000, 5000000))
plt.xlabel("Range 2M to 5M")
plt.ylabel("Frequency")
plt.title("Histogram plot of the Grand Canyon")
plt.show()

# %% [markdown]
# ## Multiple Histogram

# %%
plt.hist(np_data['GrandCanyon'],
        facecolor="lightgreen",
        edgecolor="blue",
        bins=10)
plt.hist(np_data['BryceCanyon'],
        facecolor="orangered",
        edgecolor="maroon",
        bins=10)
plt.hist(np_data['Badlands'],
        facecolor="blue",
        edgecolor="red",
        bins=3)
plt.legend(["Grand Canyon", "BryceCanyon", "Badlands"])
plt.xlabel("Range")
plt.ylabel("Frequency")
plt.title("Histogram plot of the Grand Canyon and Bryce Canyon")
plt.show()

# %% [markdown]
# ## 2  Pie Chart: Pie chart shows distribution of data based on proportion of pie occupied.

# %% [markdown]
# #### Importing Libraries and Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#movie data
movie_data=pd.read_csv("types_movies.csv")

# %%
movie_data.head()
# Out:
#     Sector  Percentage
# 0   Sci-Fi          20
# 1    Drama          35
# 2   Action          25
# 3   Comedy           5
# 4  Romance          15

# %%
plt.pie(movie_data['Percentage'],
       labels=movie_data['Sector'])
plt.title("Pie Plot of Movie data")
plt.show()

# %% [markdown]
# #### Pie chart customizations
#  We set the values for the colors and autopct properties. The latter sets the format for the values to be displayed.

# %% [markdown]
# https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
colors_list=['darkorange','sandybrown','darksalmon','orangered','chocolate']

# %%
plt.pie(movie_data['Percentage'],
       labels=movie_data['Sector'],
       colors=colors_list,
       autopct="%.0f")
plt.title("Pie Plot of Movie data")
plt.show()

# %% [markdown]
# #### The explode property
# To highlight a particular wedge of the pie chart, we use explode to separate it from the rest of the chart.
#
# The value for "explode" represents the fraction of the radius with which to offset each wedge.

# %%
explode_list=[0, .3, 0,0,0]
plt.pie(movie_data['Percentage'],
       labels=movie_data['Sector'],
       colors=colors_list,
        explode=explode_list,
       autopct="%.0f")
plt.title("Pie Plot of Movie data")
plt.show()

# %% [markdown]
# ## 3 Time Series by line plot
# * Time series is a line plot and it is basically connecting data points with a straight line.
# * It is useful in understanding the trend over time.
# * It can explain the correlation between points by the trend.
# * An upward trend means positive correlation and downward trend means a negative correlation.
# * It mostly used in forecasting, monitoring models.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# stocks data
stock_data=pd.read_csv("stocks.csv")
stock_data.head()
# Out:
#        Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0  3-Jan-07  11.107141  38.869999  50.777351  251.001007  79.242500
# 1  1-Feb-07  10.962033  39.250000  48.082939  224.949951  74.503204
# 2  1-Mar-07  12.037377  41.700001  51.900383  229.309311  75.561348
# 3  2-Apr-07  12.930043  41.560001  54.588032  235.925919  81.934280
# 4  1-May-07  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    121 non-null    object
#  1   AAPL    121 non-null    float64
#  2   ADBE    121 non-null    float64
#  3   CVX     121 non-null    float64
#  4   GOOG    121 non-null    float64
#  5   IBM     121 non-null    float64
#  6   MDLZ    121 non-null    float64
#  7   MSFT    121 non-null    float64
#  8   NFLX    121 non-null    float64
#  9   ORCL    121 non-null    float64
#  10  SBUX    121 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 10.5+ KB

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
stock_data['Date']=pd.to_datetime(stock_data['Date'])
# Out:
# C:\Users\gavin\AppData\Local\Temp\ipykernel_26808\3223040857.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   stock_data['Date']=pd.to_datetime(stock_data['Date'])

# %% [markdown]
# ### Compare stocks side by side

# %%
fig=plt.figure(figsize=(10,6))

ax1= fig.add_axes([0,0,1,1])
ax2= fig.add_axes([.05,.05, .5, .3])

ax1.plot(stock_data['Date'],
        stock_data['AAPL'],
        color="green")
ax2.plot(stock_data['Date'],
        stock_data['IBM'],
        color="blue")
plt.title("Stocks data of Apple and IBM(inset)")
fig.show
# Out:
# <bound method Figure.show of <Figure size 1000x600 with 2 Axes>>

# %% [markdown]
# ### Compare multiple stocks

# %% [markdown]
# # https://matplotlib.org/stable/api/colors_api.html

# %%
fig=plt.figure(figsize=(15,7))
fig.suptitle("Stock price comparison 2007-2017")
ax1=fig.add_subplot(231)  # 2 row, 3 column, first plot
ax1.set_title("MSFT")
ax1.plot(stock_data['Date'],
        stock_data['IBM'],
        color="blue")
ax2=fig.add_subplot(232)  # 2 row, 3 column, first plot
ax2.set_title("Google")
ax2.plot(stock_data['Date'],
        stock_data['GOOG'],
        color="purple")
ax3=fig.add_subplot(233)  # 2 row, 3 column, first plot
ax3.set_title("SBUX")
ax3.plot(stock_data['Date'],
        stock_data['SBUX'],
        color="magenta")
ax4=fig.add_subplot(234)  # 2 row, 3 column, first plot
ax4.set_title("ADBE")
ax4.plot(stock_data['Date'],
        stock_data['ADBE'],
        color="orange")
ax5=fig.add_subplot(235)  # 2 row, 3 column, first plot
ax5.set_title("NFLX")
ax5.plot(stock_data['Date'],
        stock_data['NFLX'],
        color="red")
ax6=fig.add_subplot(236)  # 2 row, 3 column, first plot
ax6.set_title("ORCL")
ax6.plot(stock_data['Date'],
        stock_data['ORCL'],
        color="green")
plt.show()

# %% [markdown]
# ## 4 Boxplot
# Boxplot gives a nice summary of the data. It helps in understanding our distribution better.
# ![image.png](attachment:image.png)
# * The end of the box shows the upper quartile(75%)and the start of the box represents the lower quartile(25%).
# * Upper Quartile is also called 3rd quartile and similarly, Lower Quartile is also called as 1st quartile.
# * The region between lower quartile and the upper quartile is called as Inter Quartile Range(IQR) and it is used to approximate the 50% spread in the middle data(75–25=50%).

# %%
import matplotlib.pyplot as plt
import pandas as pd
# exams
exam_data=pd.read_csv("exams.csv")

# %%
exam_data
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group C            some high school  free/reduced
# 1   female        group C                some college  free/reduced
# 2     male        group A                 high school      standard
# 3     male        group B                some college      standard
# 4   female        group C             master's degree  free/reduced
# ..     ...            ...                         ...           ...
# 95  female        group D                some college      standard
# 96  female        group C             master's degree      standard
# 97    male        group E             master's degree      standard
# 98    male        group C                 high school  free/reduced
# 99    male        group E           bachelor's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                     none          69             61             58
# 1                completed          47             65             69
# 2                     none          66             52             53
# 3                     none          88             89             82
# 4                     none          62             82             76
# ..                     ...         ...            ...            ...
# 95                    none          56             59             61
# 96                    none          64             57             62
# 97               completed          62             48             38
# 98                    none          44             34             36
# 99                    none          48             48             40
#
# [100 rows x 8 columns]

# %%
exam_data.describe()
# Out:
#        math score  reading score  writing score
# count  100.000000     100.000000     100.000000
# mean    67.150000      69.180000      67.780000
# std     12.797865      13.832607      14.874954
# min     36.000000      34.000000      33.000000
# 25%     56.000000      60.000000      57.750000
# 50%     68.000000      69.000000      68.500000
# 75%     76.000000      80.000000      77.250000
# max     95.000000      99.000000     100.000000

# %%
exam_data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
exam_scores=exam_data[['math score',
                      'reading score',
                      'writing score']]

# %%
exam_scores.head()
# Out:
#    math score  reading score  writing score
# 0          69             61             58
# 1          47             65             69
# 2          66             52             53
# 3          88             89             82
# 4          62             82             76

# %% [markdown]
# ###  Box plots

# %%
colors=['blue','red','green']
BP=plt.boxplot(exam_scores,
           patch_artist=True,
           notch=True)
plt.xticks([1,2,3], ['math score', 'reading score', 'writing score'])
plt.title("Box plot of exam scores")
plt.ylabel('scores')

for patch, color in zip(BP['boxes'],colors):
    patch.set_facecolor(color)

plt.show()

# %% [markdown]
# ### Violin Plots
# Violin plot is a better chart than boxplot as it gives a much broader understanding of the distribution. It resembles a violin and dense areas point the more distribution of data otherwise hidden by box plots

# %%
plt.violinplot(exam_scores,
              showmedians=True)
plt.xticks([1,2,3], ['math score', 'reading score', 'writing score'])
plt.title("Violin plot plot of exam scores")
plt.ylabel('scores')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## TwinAxis
# * TwinAxis helps in visualizing plotting 2 plots w.r.t to the y-axis and same x-axis.
# * It should when we require 2 plots or grouped data in the same direction.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# austin weather
austin_weather=pd.read_csv("austin_weather.csv")
austin_weather.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
#   SeaLevelPressureAvgInches SeaLevelPressureLowInches VisibilityHighMiles  \
# 0                     29.68                     29.59                  10
# 1                     30.13                     29.87                  10
# 2                     30.49                     30.41                  10
# 3                     30.45                      30.3                  10
# 4                     30.33                     30.27                  10
#
#   VisibilityAvgMiles VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  7                  2          20          4          31
# 1                 10                  5          16          6          25
# 2                 10                 10           8          3          12
# 3                 10                  7          12          4          20
# 4                 10                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T
#
# [5 rows x 21 columns]

# %%
austin_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
#  13  VisibilityHighMiles         1319 non-null   object
#  14  VisibilityAvgMiles          1319 non-null   object
#  15  VisibilityLowMiles          1319 non-null   object
#  16  WindHighMPH                 1319 non-null   object
#  17  WindAvgMPH                  1319 non-null   object
#  18  WindGustMPH                 1319 non-null   object
#  19  PrecipitationSumInches      1319 non-null   object
#  20  Events                      1319 non-null   object
# dtypes: int64(3), object(18)
# memory usage: 216.5+ KB

# %% [markdown]
# #### Extracting Date,Avg Temperature and Avg Wind Speed columns

# %%
data_weather=austin_weather[['Date',
                             'TempAvgF',
                             'WindAvgMPH']].head(30)
data_weather.head()
# Out:
#          Date  TempAvgF WindAvgMPH
# 0  2013-12-21        60          4
# 1  2013-12-22        48          6
# 2  2013-12-23        45          3
# 3  2013-12-24        46          4
# 4  2013-12-25        50          2

# %%
data_weather['Date']=pd.to_datetime(data_weather['Date'])

# %% [markdown]
# ### Plotting two lines with 2 separate Y axes with the same X axis
# First create one axis and then use the twinx() function to create another axis sharing the same X axis
# ![image.png](attachment:image.png)

# %%
fig,ax1=plt.subplots()
fig=plt.figure(figsize=(12,6))
# set x label
ax1.set_xlabel("Date")
#add tick parameters, bottom level disable
ax1.tick_params(axis="x",
               bottom=False,
               labelbottom=False)
# set y label in the left side
ax1.set_ylabel("Temp(F)",
              color="red",
              size="x-large")
# tick params of y
ax1.tick_params(axis="y",
               labelcolor="red",
               labelsize="large")
# plot average temperature and date
ax1.plot(data_weather['Date'],
        data_weather['TempAvgF'],
        color="red")
ax2=ax1.twinx()
# set y label
ax2.set_ylabel("Avgt Wind Speed (MPH)",
               color="blue",
               size='x-large')
# ticks
ax2.tick_params(axis="y",
               labelcolor="blue",
               labelsize="large")
ax2.plot(data_weather['Date'],
        data_weather['WindAvgMPH'],
         color="blue")

plt.show()

# %% [markdown]
# ### Twin axis for the same data
# If the same data can be expressed in different units, we can configure our axis to display both units on two axes.
# ![image.png](attachment:image.png)

# %%
def f2c(f):
    return (f-32)*5/9

# %%
fig,ax1=plt.subplots()
fig=plt.figure(figsize=(12,6))
# set x label
ax1.set_xlabel("Date")
#add tick parameters, bottom level disable
ax1.tick_params(axis="x",
               bottom=False,
               labelbottom=False)
# set y label in the left side
ax1.set_ylabel("Temp(F)",
              color="red",
              size="x-large")
# tick params of y
ax1.tick_params(axis="y",
               labelcolor="red",
               labelsize="large")
# plot average temperature and date
ax1.plot(data_weather['Date'],
        data_weather['TempAvgF'],
        color="green")
ax2=ax1.twinx()
# get the minimum and maximum of average temp in farenheit
ymin,ymax=ax1.get_ylim()
#print(ymin)
# set y min  and y max for average temp in celsius
ax2.set_ylim(f2c(ymin), f2c(ymax))
ax2.set_ylabel("Temp(C)",
              color="blue",
              size="large")
# tick params of y
ax2.tick_params(axis="y",
               labelcolor="blue",
               labelsize="large")

plt.show()

# %% [markdown]
# ## 6 Stack Plot
# * Stack plot visualizes data in stacks and shows the distribution of data over time.
# * It is used for checking multiple variable area plots in a single plot.

# %%
import matplotlib.pyplot as ply
import pandas as pd
data_np=pd.read_csv("national_parks.csv")
data_np.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
x=data_np['Year']
y=np.vstack([data_np['Badlands'],
           data_np['GrandCanyon'],
             data_np['BryceCanyon']])

# %%
data_np.columns
# Out:
# Index(['Year', 'Badlands', 'GrandCanyon', 'BryceCanyon'], dtype='object')

# %%
labels=['Badlands', 'GrandCanyon', 'BryceCanyon']

# %%
colors=['green','red','blue']
plt.stackplot(x,y,labels=labels,
            colors=colors,
            edgecolor='black')
plt.legend(loc=3)
plt.show()

# %% [markdown]
# ### Percentage stack plot

# %%
data_percent=data_np.divide(data_np.sum(axis=1), axis=0)

# %%
plt.stackplot(x,data_percent['Badlands'],
             data_percent['GrandCanyon'],
             data_percent['BryceCanyon'],
             labels=labels,
            colors=colors,
            edgecolor='black')
plt.legend(loc="center left", bbox_to_anchor=(1,0.5))
plt.show()

# %% [markdown]
# ## 7 Bar Plot
# * Bar Plot shows the distribution of data over several groups.
# * It is commonly confused with a histogram which only takes numerical data for plotting.
# * It helps in comparing multiple numeric values.

# %%
import matplotlib.pyplot as ply
import pandas as pd
countries=pd.read_csv("countries.csv")
countries.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
countries['year'].value_counts()
# Out:
# year
# 1952    142
# 1957    142
# 1962    142
# 1967    142
# 1972    142
# 1977    142
# 1982    142
# 1987    142
# 1992    142
# 1997    142
# 2002    142
# 2007    142
# Name: count, dtype: int64

# %%
data_2007=countries[countries['year']==2007]
data_2007.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 142 entries, 11 to 1703
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         142 non-null    object
#  1   continent       142 non-null    object
#  2   year            142 non-null    int64
#  3   lifeExpectancy  142 non-null    float64
#  4   population      142 non-null    int64
#  5   gdpPerCapita    142 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 7.8+ KB

# %% [markdown]
# ### selecting top 10 populated countries

# %%
top_10_p=data_2007.sort_values('population',
                               ascending=False).head(10)

# %%
top_10_p
# Out:
#             country continent  year  lifeExpectancy  population  gdpPerCapita
# 299           China      Asia  2007          72.961  1318683096   4959.114854
# 707           India      Asia  2007          64.698  1110396331   2452.210407
# 1619  United States  Americas  2007          78.242   301139947  42951.653090
# 719       Indonesia      Asia  2007          70.650   223547000   3540.651564
# 179          Brazil  Americas  2007          72.390   190010647   9065.800825
# 1175       Pakistan      Asia  2007          65.483   169270617   2605.947580
# 107      Bangladesh      Asia  2007          64.062   150448339   1391.253792
# 1139        Nigeria    Africa  2007          46.859   135031164   2013.977305
# 803           Japan      Asia  2007          82.603   127467972  31656.068060
# 995          Mexico  Americas  2007          76.195   108700891  11977.574960

# %% [markdown]
# ### plot mean life expectency of different continents

# %%
plt.figure(figsize=(12,6))
x=range(10)
plt.bar(x, top_10_p['population'])
plt.xticks(x,top_10_p['country'])
plt.xlabel("Countries")
plt.ylabel('population in billions')
plt.title('10 most populated countries in 2007')
plt.show()

# %% [markdown]
# ### plot mean life expectency of different continents

# %%
grouped_data=countries.groupby('continent')['lifeExpectancy'].mean()
print(grouped_data)

x=range(5)
plt.bar(x,grouped_data)
plt.xticks(x,grouped_data.index)
plt.xlabel('Continents')
plt.ylabel('average life expectancy')
plt.show()
# Out:
# continent
# Africa      48.865330
# Americas    64.658737
# Asia        60.064903
# Europe      71.903686
# Oceania     74.326208
# Name: lifeExpectancy, dtype: float64

# %% [markdown]
# ## 8 Scatter Plot
# * Scatter plot helps in visualizing 2 numeric variables.
# * It helps in identifying the relationship of the data with each variable i.e correlation or trend patterns.
# * It also helps in detecting outliers in the plot.
# * It is used in Machine learning concepts like regression, where x and y are continuous variables. It is also used in clustering scatters or outlier detection.

# %%
data_2007.head()
# Out:
#         country continent  year  lifeExpectancy  population  gdpPerCapita
# 11  Afghanistan      Asia  2007          43.828    31889923    974.580338
# 23      Albania    Europe  2007          76.423     3600523   5937.029526
# 35      Algeria    Africa  2007          72.301    33333216   6223.367465
# 47       Angola    Africa  2007          42.731    12420476   4797.231267
# 59    Argentina  Americas  2007          75.320    40301927  12779.379640

# %%
plt.scatter(data_2007['gdpPerCapita'],
            data_2007['lifeExpectancy'])
plt.xlabel("GDP per capita ($)")
plt.ylabel("life expectancy")
plt.show()
